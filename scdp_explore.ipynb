# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('DiariasEPassagens_ultimos_2_anos.csv')
# Out:
# C:\Users\Primodeckers\AppData\Local\Temp\ipykernel_8876\2357773508.py:1: DtypeWarning: Columns (0: Município origem, 1: UF origem, 2: Município destino, 3: UF destino) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('DiariasEPassagens_ultimos_2_anos.csv')

# %%
df.head()
# Out:
#    Código órgão superior       Nome órgão superior  Código órgão  \
# 0                  20000  PRESIDENCIA DA REPUBLICA         20000
# 1                  20000  PRESIDENCIA DA REPUBLICA         20000
# 2                  20000  PRESIDENCIA DA REPUBLICA         20000
# 3                  20000  PRESIDENCIA DA REPUBLICA         20000
# 4                  20000  PRESIDENCIA DA REPUBLICA         20000
#
#                  Nome órgão  Código unidade gestora  \
# 0  PRESIDENCIA DA REPUBLICA                110037.0
# 1  PRESIDENCIA DA REPUBLICA                110037.0
# 2  PRESIDENCIA DA REPUBLICA                110037.0
# 3  PRESIDENCIA DA REPUBLICA                110037.0
# 4  PRESIDENCIA DA REPUBLICA                110037.0
#
#              Nome unidade gestora          Nome servidor Cargo  \
# 0  SECT DE SEG PRESIDENCIAL/GSIPR  ACACIO PEREIRA CAMPOS   NaN
# 1  SECT DE SEG PRESIDENCIAL/GSIPR  ACACIO PEREIRA CAMPOS   NaN
# 2  SECT DE SEG PRESIDENCIAL/GSIPR  ACACIO PEREIRA CAMPOS   NaN
# 3  SECT DE SEG PRESIDENCIAL/GSIPR  ACACIO PEREIRA CAMPOS   NaN
# 4  SECT DE SEG PRESIDENCIAL/GSIPR  ACACIO PEREIRA CAMPOS   NaN
#
#   Data início viagem  Data término viagem  ...       Término trecho  \
# 0         2017-03-20  2017-03-24 00:00:00  ...  2017-03-24 00:00:00
# 1         2017-03-20  2017-03-24 00:00:00  ...  2017-03-24 00:00:00
# 2         2017-06-30  2017-07-02 00:00:00  ...  2017-07-02 00:00:00
# 3         2017-06-30  2017-07-02 00:00:00  ...  2017-07-02 00:00:00
# 4         2017-08-14  2017-08-15 00:00:00  ...  2017-08-15 00:00:00
#
#   Município origem UF origem Município destino UF destino Número diárias  \
# 0              NaN       NaN               NaN        NaN           2,00
# 1              NaN       NaN               NaN        NaN            ,50
# 2              NaN       NaN               NaN        NaN           1,00
# 3              NaN       NaN               NaN        NaN            ,50
# 4              NaN       NaN               NaN        NaN            ,50
#
#   Valor diárias Meio de transporte Categoria passagem Valor passagem
# 0        642,56    Veículo Oficial                NaN              0
# 1        160,64    Veículo Oficial                NaN              0
# 2        386,36    Veículo Oficial                NaN              0
# 3        193,18    Veículo Oficial                NaN              0
# 4           182    Veículo Oficial                NaN              0
#
# [5 rows x 23 columns]
